# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np


df = pd.read_csv(
    'data/processing/data.csv',
    low_memory=False,
    parse_dates=['issue_date']
)

df.describe()
# Out:
#           loan_amnt   funded_amnt      int_rate    annual_inc           dti  \
# count  2.260668e+06  2.260668e+06  2.260668e+06  2.260664e+06  2.258957e+06
# mean   1.504693e+04  1.504166e+04  1.309291e+01  7.799243e+04  1.882420e+01
# std    9.190245e+03  9.188413e+03  4.832114e+00  1.126962e+05  1.418333e+01
# min    5.000000e+02  5.000000e+02  5.310000e+00  0.000000e+00 -1.000000e+00
# 25%    8.000000e+03  8.000000e+03  9.490000e+00  4.600000e+04  1.189000e+01
# 50%    1.290000e+04  1.287500e+04  1.262000e+01  6.500000e+04  1.784000e+01
# 75%    2.000000e+04  2.000000e+04  1.599000e+01  9.300000e+04  2.449000e+01
# max    4.000000e+04  4.000000e+04  3.099000e+01  1.100000e+08  9.990000e+02
#
#           revol_bal   total_pymnt
# count  2.260668e+06  2.260668e+06
# mean   1.665846e+04  1.182403e+04
# std    2.294831e+04  9.889599e+03
# min    0.000000e+00  0.000000e+00
# 25%    5.950000e+03  4.272580e+03
# 50%    1.132400e+04  9.060870e+03
# 75%    2.024600e+04  1.670797e+04
# max    2.904836e+06  6.329688e+04

# %%
from tools.helpers import read_json

data = read_json('project_config.json')

for col in data['keep_columns']:
    print(col)
# Out:
# loan_amnt
# funded_amnt
# term
# int_rate
# grade
# annual_inc
# issue_d
# dti
# revol_bal
# total_pymnt
# loan_status

# %%
# for col in data['keep_columns']:

#     df[col].hist()

df[''].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/GitHub/assignment/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-b9b6f884d2ec> in <module>
#       3 #     df[col].hist()
#       4
# ----> 5 df[''].hist()
#
# ~/Documents/GitHub/assignment/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/Documents/GitHub/assignment/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %%
df.sort_values('issue_date', ascending=True).tail(20)

# %%
df['max_date'] = pd.to_datetime(df.issue_date.max())

df.dtypes
# Out:
# loan_amnt               int64
# funded_amnt             int64
# term                   object
# int_rate              float64
# grade                  object
# annual_inc            float64
# issue_d                object
# loan_status            object
# dti                   float64
# revol_bal               int64
# total_pymnt           float64
# issue_date     datetime64[ns]
# max_date       datetime64[ns]
# dtype: object

# %%
import numpy as np

df['nb_months'] = ((df.max_date - df.issue_date)/np.timedelta64(1, 'M'))
df['nb_months'] = df['nb_months'].astype(int)

df['months'] = (
    (df.max_date - df.issue_date) / np.timedelta64(1, 'M')
).astype(int)

# %%
df
# Out:
#          loan_amnt  funded_amnt        term  int_rate grade  annual_inc  \
# 0             2500         2500   36 months     13.56     C     55000.0
# 1            30000        30000   60 months     18.94     D     90000.0
# 2             5000         5000   36 months     17.97     D     59280.0
# 3             4000         4000   36 months     18.94     D     92000.0
# 4            30000        30000   60 months     16.14     C     57250.0
# 5             5550         5550   36 months     15.02     C    152500.0
# 6             2000         2000   36 months     17.97     D     51000.0
# 7             6000         6000   36 months     13.56     C     65000.0
# 8             5000         5000   36 months     17.97     D     53580.0
# 9             6000         6000   36 months     14.47     C    300000.0
# 10            5500         5500   36 months     22.35     D     50000.0
# 11           28000        28000   60 months     11.31     B     70000.0
# 12           11200        11200   36 months      8.19     A     65000.0
# 13            6500         6500   36 months     17.97     D    154000.0
# 10      2018-12-01 2018-12-01          0       0
# 11      2018-12-01 2018-12-01          0       0
# 12      2018-12-01 2018-12-01          0       0
# 13      2018-12-01 2018-12-01          0       0
# 14      2018-12-01 2018-12-01          0       0
# 15      2018-12-01 2018-12-01          0       0
# 16      2018-12-01 2018-12-01          0       0
# 17      2018-12-01 2018-12-01          0       0
# 18      2018-12-01 2018-12-01          0       0
# 19      2018-12-01 2018-12-01          0       0
# 20      2018-12-01 2018-12-01          0       0
# 21      2018-12-01 2018-12-01          0       0
# 22      2018-12-01 2018-12-01          0       0
# 23      2018-12-01 2018-12-01          0       0
# 24      2018-12-01 2018-12-01          0       0
# 25      2018-12-01 2018-12-01          0       0
# 26      2018-12-01 2018-12-01          0       0
# 27      2018-12-01 2018-12-01          0       0
# 28      2018-12-01 2018-12-01          0       0
# 29      2018-12-01 2018-12-01          0       0
# ...            ...        ...        ...     ...
# 2260638 2017-10-01 2018-12-01         13      13
# 2260639 2017-10-01 2018-12-01         13      13
# 2260640 2017-10-01 2018-12-01         13      13
# 2260641 2017-10-01 2018-12-01         13      13
# 2260642 2017-10-01 2018-12-01         13      13
# 2260643 2017-10-01 2018-12-01         13      13
# 2260644 2017-10-01 2018-12-01         13      13
# 2260645 2017-10-01 2018-12-01         13      13
# 2260646 2017-10-01 2018-12-01         13      13
# 2260647 2017-10-01 2018-12-01         13      13
# 2260648 2017-10-01 2018-12-01         13      13
# 2260649 2017-10-01 2018-12-01         13      13
# 2260650 2017-10-01 2018-12-01         13      13
# 2260651 2017-10-01 2018-12-01         13      13
# 2260652 2017-10-01 2018-12-01         13      13
# 2260653 2017-10-01 2018-12-01         13      13
# 2260654 2017-10-01 2018-12-01         13      13
# 2260655 2017-10-01 2018-12-01         13      13
# 2260656 2017-10-01 2018-12-01         13      13
# 2260657 2017-10-01 2018-12-01         13      13
# 2260658 2017-10-01 2018-12-01         13      13
# 2260659 2017-10-01 2018-12-01         13      13
# 2260660 2017-10-01 2018-12-01         13      13
# 2260661 2017-10-01 2018-12-01         13      13
# 2260662 2017-10-01 2018-12-01         13      13
# 2260663 2017-10-01 2018-12-01         13      13
# 2260664 2017-10-01 2018-12-01         13      13
# 2260665 2017-10-01 2018-12-01         13      13
# 2260666 2017-10-01 2018-12-01         13      13
# 2260667 2017-10-01 2018-12-01         13      13
#
# [2260668 rows x 15 columns]

# %%
dfs = df[~(df.months < 36)]

# %%
dfs.months.max()
# Out:
# 138

# %%
dfs.loan_status.unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Late (31-120 days)', 'Current',
#        'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
fully_paid_count = dfs.groupby(['loan_status']).term.count()['Fully Paid']

# %%
 dfs.groupby(['loan_status']).term.count()
# Out:
# loan_status
# Charged Off                                            151667
# Current                                                 58695
# Does not meet the credit policy. Status:Charged Off       761
# Does not meet the credit policy. Status:Fully Paid       1988
# Fully Paid                                             671159
# In Grace Period                                           918
# Late (16-30 days)                                         316
# Late (31-120 days)                                       1936
# Name: term, dtype: int64

# %%
pct_total_fully_paid = fully_paid_count / (len(dfs.index))

# %%
pct_total_fully_paid
# Out:
# 0.7562866221941765
